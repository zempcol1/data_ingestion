# %% [markdown]
# # Getting Text data from RSS-Feeds

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import feedparser
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(f'Current working directory: {os.getcwd()}')
# Out:
# Current working directory: /workspaces/data_ingestion/07_RSS_Feeds

# %% [markdown]
# ## Parse the RSS feed

# %%
# RSS feeds from NZZ website
feed = feedparser.parse("https://www.nzz.ch/startseite.rss")

# %% [markdown]
# ## Extract the data

# %%
# Get data from RSS feeds
feed_entries = feed.entries

# Initialize an empty string to store the text
wordcloud_text = ""

# Show first RSS-feeds
print("Article Titles:")
for entry in feed.entries:

    article_title = entry.title
    article_link = entry.link
    article_published_at = entry.published
    article_published_at_parsed = entry.published_parsed

    # Append the title to the wordcloud_text
    wordcloud_text += f"{article_title} "

    # Change and format output
    print(f"{article_title}")
    # print(f"{article_title}[{article_link}]")
    # print(f"Published at {article_published_at}")
# Out:
# Article Titles:
# KOMMENTAR - Zürich lechzt nach mehr günstigen Wohnungen. Deshalb jeden Vorschlag anzunehmen, wäre aber gefährlich
# Das Dorf der Superreichen – in Hergiswil treffen Schweizer Schattenkinder auf norwegische Steuerflüchtlinge
# Mit Black Hawks direkt an die Front: Der ukrainische Militärgeheimdienst greift mit einer waghalsigen Kommandoaktion in die Schlacht um Pokrowsk ein
# Land ohne Antrieb: Das Zentrum der deutschen Autoindustrie fürchtet den Stillstand
# Ramona Bachmann brach zusammen, ging in eine Klinik und verletzte sich kurz vor der EM schwer. Jetzt ist sie auf dem Weg zurück
# Abgesagte Konzerte, abgehängte Bilder, nicht ausgesprochene Wörter: die Sehnsucht nach Reinheit
# Fatima schwimmt los: Besuch in einem Schwimmkurs für Frauen aus aller Welt
# Neues Rating: In diesen Ländern sollten Sie leben, wenn Chaos auf der Welt ausbricht – die USA gehören nicht dazu
# Diese Frau führt eine Koranschule für Transgender – die wohl einzige der Welt
# Abu Ahmed sass 19 Monate ohne Anklage in einem israelischen Gefängnis – dank Trumps Friedensplan kam er wieder frei
# Cat Stevens: Der Pop-Star, der sich eines Tages entschloss, zu Allah zu beten
# «Ich bin Dreck»: Der grosse deutsche Rapper Haftbefehl zeichnet ein Bild der eigenen Zerstörung
# INTERVIEW - «Wir müssen den ukrainischen Staat, dieses Monster, mit unseren Händen stützen. Wir haben ihn mit so viel Blut verteidigt»
# Kathmandu ist ein Betondschungel geworden, Elefanten gibt es nur noch im Zoo
# Im Nahen Osten formiert sich eine neue islamistische Achse. Der entscheidende Player dabei ist: die Türkei
# In der Schweiz bricht ein Krieg aus – aber Anna Netrebko triumphiert
# Zohran Mamdani: Sozialist, Hobby-Rapper, Polizistenschreck – und vielleicht bald Bürgermeister von New York
# PODCAST «NZZ AKZENT» - Falls New York den Muslim Zohran Mamdani zum Bürgermeister wählt: Was würde das für die jüdische Gemeinschaft bedeuten?
# Für Zoppo und Zaz endet die Reise in den Süden abrupt: Kaum ist der Flug über die Alpen geschafft, werden die Vögel in Italien getötet
# München will zum zweiten Mal die Olympischen Sommerspiele ausrichten, doch die internationale Konkurrenz ist gross
# ERKLÄRT - Mehr als sechzig Tote im Konflikt zwischen den USA und Venezuela – Karten und Grafiken zeigen, warum die Lage weiter eskaliert
# SPONSORED CONTENT - Innovation in der DNA: Wie zwei Partner die Logistikbranche revolutionieren
# INTERVIEW - «Europa könnte die irreguläre Migration drastisch reduzieren», sagt Gerald Knaus. Der Migrationsexperte hat einen Plan
# «Die USA verspüren keinen Leidensdruck» – die verzweifelte Suche nach dem Trump-Moment im Zollstreit
# Die von den USA angeführte Weltordnung zerfällt: Singapur muss sich neu erfinden
# Indischer Ölkonzern von Lakshmi Mittal stoppt Importe aus Russland nach Enthüllungen über Tanker
# GASTKOMMENTAR - Kleinere Mächte, die ohne Schutz bleiben, könnten sich bald die Atombombe zulegen
# Im Netflix-Film «A House of Dynamite» können die USA eine Atomrakete nicht abwehren. Auch Europa muss erkennen: Das ist mehr als Fiktion
# In dieser Lagerhalle überwachen die USA den Waffenstillstand in Gaza – Israel spielt nur eine Nebenrolle
# «Wir brauchen mehr Warschau in Berlin» – Deutschlands Wirtschaft entdeckt in Polen ein neues Vorbild
# Ein Star-Werber hat die Corona-Kampagne des Bundes entwickelt. Nun hat er wieder eine schwierige Aufgabe: Er soll im rot-grünen Zürich einen Liberalen zum Stapi machen
# Patienten mit Flecken im Gesicht erhalten eine 2400 Franken teure Salbe – aber nur, wenn sie vorher eine Psychotherapie machen
# Das Bussen-Wunder von Birsfelden: Jetzt wollen auch andere Gemeinden die Ortsdurchfahrt mit Kameras überwachen
# Pflegeeltern auf Mission: Evangelikale üben Druck auf Pflegekinder aus
# Hat er das Zeug zum Mr. Post? Diese Baustellen warten auf den neuen CEO Pascal Grieder
# So erben und vererben Sie richtig – das sind die wichtigsten Punkte
# KOMMENTAR - Die Regulierungs-Illusion – oder warum im KI-Zeitalter Eigenverantwortung wichtiger denn je ist
# KOMMENTAR - Erdogan ist der Mann der Stunde: Geschickt mischt sich die Türkei auf der ganzen Welt ein
# KOMMENTAR - Rot-Grün will SUV-Halter mit schmaleren Strassen drangsalieren. Das zeigt, wie kindisch die Stadtzürcher Verkehrspolitik geworden ist
# KOMMENTAR - Es braucht mehr Konsequenz gegen Krawallmacher – aber nicht so, wie es sich manche Politiker vorstellen
# DER ANDERE BLICK - Deutschland erstickt an seinen Problemen, doch das Land flüchtet sich in eine Scheinwelt
# KOMMENTAR - EU-Verträge: Die Vernehmlassung hat vieles ans Licht gebracht – jetzt muss der Bundesrat dringend nachbessern
# KOMMENTAR - Bitte sterben Sie gesund!
# KOMMENTAR - Selbst Sam Altman spricht von einer KI-Blase: An der Börse ist eine Korrektur fällig
# INTERVIEW - «Antisemitismus als Tugend zu vermarkten, ist nicht nur erschreckend, es wäre monströs», sagt der Schauspieler Christian Berkel
# Gefangen im Kopfkino: Wenn Tagträume zur Sucht werden
# «Tagsüber üben, abends Kühe streicheln»: Die Sopranistin Sarah Maria Sun sprengt mit Hingabe klassische Erwartungen
# Die Stimmen der Lebenden und der Toten – Kevin Chens polyfoner Roman über die Selbstbefreiung eines Taiwaners in Berlin
# Das Wissen über das Gehirn nimmt zu, das bedroht die Psychiatrie
# PODCAST «NZZ QUANTENSPRUNG» - Der stärkste Hurrikan des Jahres zeigt, wie gut KI Stürme vorhersagen kann. Doch Warnungen retten nur Leben, wenn Menschen auf sie hören
# Hurrikan «Melissa» zieht eine Schneise der Verwüstung durch die Karibik – mindestens 59 Personen kamen durch den Wirbelsturm ums Leben
# Künstliche Intelligenz sagt das Wetter genauer vorher als herkömmliche Modelle – in Europa soll das bald allen nützen
# Die Reichweite nützlicher Wettervorhersagen wird sich noch um mehrere Tage in die Zukunft verlagern
# Regengüsse verlässlich vorherzusagen, ist für Wetterdienste immer noch eine grosse Herausforderung – gerade bei Gewittern
# Die erste Wettervorhersage: Ende des Ersten Weltkriegs erkannten Forscher, wie das funktioniert
# Newsletter «Quantensprung»: Die grossen Fragen aus Wissenschaft und Technologie auf dem Prüfstand – jeden Freitag in Ihrem Postfach
# Warren Buffett weiss nicht, wohin mit seinem Geld
# Die Schönen und Reichen auf der Upper East Side könnten bald von einem Sozialisten regiert werden. Wie beunruhigt ist New Yorks Oberschicht?
# INTERVIEW - Alexander Gauland: «Ich habe wegen der AfD praktisch alle meine Freunde verloren und einen Teil meiner Familie»
# «Streiten kann man beim Erben immer, auch wenn es perfekt geplant ist», sagt die Erbrechtsexpertin Tamara Völk
# Der japanische Baseballstar Yoshinobu Yamamoto macht sich mit einer Finaldarbietung für die Ewigkeit über Nacht unsterblich
# GASTKOMMENTAR - Der Drang zu Schreiben gründet tief
# DER ANDERE BLICK - Deutschlands verrückte Abschiebe-Debatte: Wer soll Syrien denn wieder aufbauen, wenn nicht junge syrische Männer?
# GASTKOMMENTAR - Der Tod – allgegenwärtig und verdrängt
# Ein Jahr nach der Flut in Spanien tritt Valencias Regierungschef zurück – ein Mittagessen wird ihm zum Verhängnis
# «Nicht selbst einschränken»: Der Generalinspekteur der Bundeswehr lehnt ein Losverfahren zur Rekrutierung ab
# Blutige Bilanz nach heftigen Protesten während der Präsidentschaftswahl in Tansania
# Die Migros fordert von Lindt: Schokolade muss wieder billiger werden
# Der Mann, der den Motorsport neu erfinden will: Nach dem Verkauf seiner Softwarefirma gibt Francisco Fernandez erneut Vollgas
# Bitcoin müsste in diesen Tagen eigentlich neue Preisrekorde brechen, doch die Stimmung am Markt für Kryptowährungen ist schlecht. Was läuft schief?
# Nicht KI, sondern das iPhone 17 beflügelt Apples Umsatz
# «Erhebliche Schwächung der digitalen Souveränität»: Armeechef Süssli ist mit seiner Warnung vor Microsoft nicht allein
# Neuer Vorschlag gegen die Zuwanderungsinitiative der SVP: Inländer sollen bei der Wohnungssuche Vorrang haben
# «Sehenden Auges in die Katastrophe»: Die Kritik an Röstis Stromabkommen kommt von fast überall
# Ein junger Mann wähnt sich in der Apokalypse. Dann geht er mit Messer und Hammer auf seine Eltern los
# Kaum eine Berufsgruppe ist so stark suizidgefährdet wie die Bäuerinnen und Bauern. Doch sie leiden im Stillen
# Eine Rentnerin sitzt regelmässig ohne Führerschein am Steuer. Die Staatsanwältin sagt: «Sobald sie ein Auto in die Finger kriegt, fährt sie»
# Mit dem torlosen Match gegen Basel beginnt für YB das teure Versprechen Gerardo Seoane
# Der FC Liverpool steckt in der Krise – das Team funktioniert mit den teuren Neuzugängen nicht wie erhofft
# Was ist der Mensch? Für den deutschen Bildhauer Wilhelm Lehmbruck war Denken Plastik und Plastik Denken.
# Medien im Krieg – trotz Verboten von prorussischen Sendern und Kritik der EU gibt es in der Ukraine guten Journalismus
# SERIE - In Gstaad trägt Roman Polanski eine Fussfessel, nachdem die USA einen Haftbefehl erlassen haben. Einst floh er in der Trauer hierher
# «Wer seine Kinder nicht impfen lässt, lässt auch seine Hunde nicht impfen»
# Endlich gibt es Mittel gegen RS-Viren. Erste Erfahrungen aus dem echten Leben bestätigen: Sie wirken
# Mit der Krankheit leben und lieben, solange es geht

# %% [markdown]
# ## Generate a WordCloud

# %%
# Generate the word cloud
wordcloud = WordCloud(width=800, 
                      height=400, 
                      background_color='black').generate(wordcloud_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Hide the axes
plt.show()

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-11-03 11:56:05
# Python Version: 3.11.13
# -----------------------------------
